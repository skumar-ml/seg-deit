# %%
import glob
import cv2
import skimage
import numpy as np
import matplotlib.pyplot as plt

# %%
data_dir = "../../../data/sb56/data/Imagenet/train/n07745940/"
images = glob.glob(data_dir + "*.JPEG")
print(len(images))
print(images)
# Out:
# 1300
# ['../../../data/sb56/data/Imagenet/train/n07745940/n07745940_8923.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_17650.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_2244.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_10884.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_11954.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_2044.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_13239.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_9485.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_1218.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_12570.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_10788.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_6142.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_2103.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_5132.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_9963.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_18495.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_6853.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_738.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_9774.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_4180.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_7596.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_10787.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_3136.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_13451.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_4469.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_2642.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_2675.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_8151.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_5400.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_5694.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_8867.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_11967.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_4024.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_7097.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_9011.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_6591.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_13025.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_7518.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_509.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_9820.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_8284.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_13964.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_9640.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_12067.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_5788.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_8515.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_20905.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_13832.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_7291.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_13252.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_12135.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_11883.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_20242.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_7155.JPEG', '../../../data/sb56/data/Imagenet/train/n07745940/n07745940_7035.JPEG', '../../../data/sb56/da ...

# %%
def _weight_mean_color(graph, src, dst, n):
    """Callback to handle merging nodes by recomputing mean color.

    The method expects that the mean color of `dst` is already computed.

    Parameters
    ----------
    graph : RAG
        The graph under consideration.
    src, dst : int
        The vertices in `graph` to be merged.
    n : int
        A neighbor of `src` or `dst` or both.

    Returns
    -------
    data : dict
        A dictionary with the `"weight"` attribute set as the absolute
        difference of the mean color between node `dst` and `n`.
    """

    diff = graph.nodes[dst]['mean color'] - graph.nodes[n]['mean color']
    diff = np.linalg.norm(diff)
    return {'weight': diff}


def merge_mean_color(graph, src, dst):
    """Callback called before merging two nodes of a mean color distance graph.

    This method computes the mean color of `dst`.

    Parameters
    ----------
    graph : RAG
        The graph under consideration.
    src, dst : int
        The vertices in `graph` to be merged.
    """
    graph.nodes[dst]['total color'] += graph.nodes[src]['total color']
    graph.nodes[dst]['pixel count'] += graph.nodes[src]['pixel count']
    graph.nodes[dst]['mean color'] = (graph.nodes[dst]['total color'] /
                                      graph.nodes[dst]['pixel count'])
    
def merge_segments(img, segmentation_mask, num_segments_desired):
    num_segs = len(np.unique(segmentation_mask))

    # Merge nodes while loop
    while num_segs > num_segments_desired:

        # Create RAG
        g = skimage.graph.rag_mean_color(img, segmentation_mask)
        print(g)
        
        # Initialize
        num_edges = g.number_of_edges()
        weights_list = [None] * num_edges

        # Iterate and determine threshold weight for merging
        i = 0
        for edge in g.edges:
            # Get the weight of the edge
            weight = g[edge[0]][edge[1]]['weight']
            
            # print(f'Edge: {edge}, Weight: {weight}')
            weights_list[i] = weight
            i += 1

        weights_list.sort()
        # print(weights_list)

        reduce_num = num_segs - num_segments_desired
        reduce_num = 1 if reduce_num <= 0 else reduce_num # After certain amount, only remove 1 by 1
        threshold = weights_list[reduce_num]
        print(threshold)
        print(weights_list)

        # Merge based on threshold
        segmentation_mask = skimage.graph.merge_hierarchical(segmentation_mask, g, thresh=threshold, rag_copy=False,
                                        in_place_merge=True,
                                        merge_func=merge_mean_color,
                                        weight_func=_weight_mean_color)
        
        num_segs = len(np.unique(segmentation_mask))
        

    return segmentation_mask

# %%
# User variables
img_stop_index = 100
num_segments_desired = 196

for i in range(img_stop_index):
    # Load image and resize
    img_path = images[i]
    img = cv2.imread(img_path)
    img = cv2.resize(img, (224, 224))
    
    # Apply segmentation 
    # segmentation_mask = skimage.segmentation.felzenszwalb(img, scale=100, sigma=0.5, min_size=150)
    segmentation_mask = skimage.segmentation.slic(img, n_segments=196, start_label=0, min_size_factor=0.5, max_size_factor=10)
    start_segs = len(np.unique(segmentation_mask))

    # out_mask = merge_segments(img, segmentation_mask, num_segments_desired)
    # end_segs = len(np.unique(out_mask))

    # print(f"Starting segments: {start_segs} | Ending segments {end_segs}")
    print(f"Starting segments: {start_segs}")
# Out:
# Starting segments: 91
# Starting segments: 151
# Starting segments: 136
# Starting segments: 136
# Starting segments: 157
# Starting segments: 177
# Starting segments: 178
# Starting segments: 141
# Starting segments: 163
# Starting segments: 174
# Starting segments: 145
# Starting segments: 159
# Starting segments: 140
# Starting segments: 153
# Starting segments: 148
# Starting segments: 152
# Starting segments: 166
# Starting segments: 129
# Starting segments: 140
# Starting segments: 162
# Starting segments: 161
# Starting segments: 86
# Starting segments: 64
# Starting segments: 159
# Starting segments: 131
# Starting segments: 126
# Starting segments: 99
# Starting segments: 127
# Starting segments: 146
# Starting segments: 154
# Starting segments: 151
# Starting segments: 157
# Starting segments: 130
# Starting segments: 140
# Starting segments: 165
# Starting segments: 125
# Starting segments: 86
# Starting segments: 134
# Starting segments: 129
# Starting segments: 179
# Starting segments: 122
# Starting segments: 141
# Starting segments: 140
# Starting segments: 150
# Starting segments: 132
# Starting segments: 161
# Starting segments: 164
# Starting segments: 146
# Starting segments: 122
# Starting segments: 105
# Starting segments: 158
# Starting segments: 41
# Starting segments: 158
# Starting segments: 155
# Starting segments: 156
# Starting segments: 129
# Starting segments: 159
# Starting segments: 152
# Starting segments: 171
# Starting segments: 171
# Starting segments: 96
# Starting segments: 117
# Starting segments: 185
# Starting segments: 135
# Starting segments: 137
# Starting segments: 159
# Starting segments: 133
# Starting segments: 138
# Starting segments: 109
# Starting segments: 125
# Starting segments: 139
# Starting segments: 144
# Starting segments: 145
# Starting segments: 173
# Starting segments: 156
# Starting segments: 144
# Starting segments: 122
# Starting segments: 156
# Starting segments: 136
# Starting segments: 158
# Starting segments: 151
# Starting segments: 156
# Starting segments: 119
# Starting segments: 123
# Starting segments: 158
# Starting segments: 134
# Starting segments: 179
# Starting segments: 165
# Starting segments: 158
# Starting segments: 126
# Starting segments: 146
# Starting segments: 145
# Starting segments: 114
# Starting segments: 155
# Starting segments: 85
# Starting segments: 71
# Starting segments: 93
# Starting segments: 99
# Starting segments: 139
# Starting segments: 62

# %%
plt.figure()
plt.imshow(img)

plt.figure()
out = skimage.color.label2rgb(segmentation_mask, img, kind='avg', bg_label=0)
plt.imshow(out)
plt.title('Initial segmentation')

# plt.figure()
# out = skimage.color.label2rgb(out_mask, img, kind='avg', bg_label=0)
# plt.imshow(out)
# plt.title('Initial segmentation')
# Out:
# Text(0.5, 1.0, 'Initial segmentation')
